# %% [markdown]
# # How to Train Detectron2 for Custom Instance Segmentation
#
# This tutorial is based on the [Detectron2 repository](https://github.com/facebookresearch/detectron2) by Facebook. This notebook shows training on **your own custom instance segmentation objects**.
#
# ### Accompanying Blog Post
#
# We recommend that you follow along in this notebook while reading the blog post on [how to train Detectron2 for custom instance segmentation](https://blog.roboflow.ai/custom-detectron2-instance-segmentation/), concurrently.
#
# ### Steps Covered in this Tutorial
#
# In this tutorial, we will walk through the steps required to train Detectron2 on your custom instance segmentation objects. We use a public [American Sign Language instance segmentation dataset](https://public.roboflow.ai/object-detection/bccd), which is open source and free to use. You can also use this notebook on your own data.
#
# To train our segmenter we take the following steps:
#
# * Install Detectron2 dependencies
# * Download custom instance segmentation data from Roboflow
# * Visualize Detectron2 training data
# * Write our Detectron2 Training configuration
# * Run Detectron2 training
# * Evaluate Dectron2 performance
# * Run Detectron2 inference on test images
# * Export saved Detectron2 weights for future inference
#
# ### **About**
#
# [Roboflow](https://roboflow.com) enables teams to deploy custom computer vision models quickly and accurately. Convert data from to annotation format, assess dataset health, preprocess, augment, and more. It's free for your first 1000 source images.
#
# **Looking for a vision model available via API without hassle? Try Roboflow Train.**
#
# ![Roboflow Wordmark](https://i.imgur.com/dcLNMhV.png)

# %% [markdown]
# # Install Roboflow and Detectron2 Pip Packages, Import Deps

# %%
# !python -m pip install roboflow
# !python -m pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting roboflow
#   Downloading roboflow-1.0.5-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: certifi==2022.12.7 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2022.12.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.22.4)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.4)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.65.0)
# Requirement already satisfied: opencv-python>=4.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.7.0.72)
# Collecting idna==2.10
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.3 MB/s eta 0:00:00
# Collecting cycler==0.10.0
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.15)
# Collecting pyparsing==2.4.7
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: chardet==4.0.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.0.0)
# Collecting requests-toolbelt
#   Downloading requests_toolbelt-0.10.1-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.27.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.39.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (23.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (2.0.12)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9676 sha256=07b0b2e1980629b4e1595b0e36695847315cb5baa78e0a9d84026c5272255844
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# Installing collected packages: wget, python-dotenv, pyparsing, idna, cycler, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.11.0
#     Uninstalling cycler-0.11.0:
#       Successfully uninstalled cycler-0.11.0
# Successfully installed cycler-0.10.0 idna-2.10 pyparsing-2.4.7 python-dotenv-1.0.0 requests-toolbelt-0.10.1 roboflow-1.0.5 wget-3.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-yj93kguo
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-yj93kguo
#   Resolved https://github.com/facebookresearch/detectron2.git to commit e020497c85873c2b811ac87dd2e4a34a806e4c2b
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.0.6)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.3.0)
# Collecting yacs>=0.1.8
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (0.8.10)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (4.65.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (2.12.2)
# Collecting fvcore<0.1.6,>=0.1.5
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7
#   Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Collecting omegaconf>=2.1
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.7 MB/s eta 0:00:00
# Collecting hydra-core>=1.1
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 17.1 MB/s eta 0:00:00
# Collecting black
#   Downloading black-23.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 53.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2==0.6) (23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 15.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (4.39.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2==0.6) (0.10.0)
# Collecting pathspec>=0.9.0
#   Downloading pathspec-0.11.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (2.0.1)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (3.3.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2==0.6) (8.1.3)
# Collecting mypy-extensions>=0.4.3
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.7.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.8.1)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.20.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.3.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.27.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (0.40.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.54.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (1.0.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2==0.6) (2.17.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from cycler>=0.10->matplotlib->detectron2==0.6) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (5.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard->detectron2==0.6) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2==0.6) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2==0.6) (3.2.2)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=7802939 sha256=bf847fee19c74d8f27ab5e41e35ea60230fe19dc2bfd5051e24a4dbb6f247a57
#   Stored in directory: /tmp/pip-ephem-wheel-cache-_hjdjkkf/wheels/47/e5/15/94c80df2ba85500c5d76599cc307c0a7079d0e221bb6fc4375
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61429 sha256=1ac6e1f1589c3528967d65ad071eefb2d18ab77edf5ab4dbd204ab7bd6f247db
#   Stored in directory: /root/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=b83662912422c38044e5f68eeeaeca501fa65542023e566be6050eb27859b871
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, portalocker, pathspec, omegaconf, mypy-extensions, iopath, hydra-core, black, fvcore, detectron2
# Successfully installed antlr4-python3-runtime-4.9.3 black-23.3.0 detectron2-0.6 fvcore-0.1.5.post20221221 hydra-core-1.3.2 iopath-0.1.9 mypy-extensions-1.0.0 omegaconf-2.3.0 pathspec-0.11.1 portalocker-2.7.0 yacs-0.1.8

# %%
import logging
import torch
from collections import OrderedDict
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.data.datasets import register_coco_instances
from detectron2.engine import DefaultTrainer
from detectron2.utils.visualizer import ColorMode
from detectron2.solver import build_lr_scheduler, build_optimizer
from detectron2.checkpoint import DetectionCheckpointer, PeriodicCheckpointer
from detectron2.utils.events import EventStorage
from detectron2.modeling import build_model
import detectron2.utils.comm as comm
from detectron2.engine import default_argument_parser, default_setup, default_writers, launch
from detectron2.data import (
    MetadataCatalog,
    build_detection_test_loader,
    build_detection_train_loader,
)
from detectron2.evaluation import (
    CityscapesInstanceEvaluator,
    CityscapesSemSegEvaluator,
    COCOEvaluator,
    COCOPanopticEvaluator,
    DatasetEvaluators,
    LVISEvaluator,
    PascalVOCDetectionEvaluator,
    SemSegEvaluator,
    inference_on_dataset,
    print_csv_format,
)

from roboflow import Roboflow

from matplotlib import pyplot as plt
from PIL import Image

# %% [markdown]
# # Download dataset via Roboflow pip package and show a sample annotation

# %%
# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="2JSTDJA0JKHBmtAvuMmQ")
project = rf.workspace("aml-dj9n6").project("vending-from-box-to-segmentation")
dataset = project.version(1).download("coco-segmentation")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Vending-from-box-to-segmentation-1 to coco-segmentation: 100% [8606597 / 8606597] bytes
# Extracting Dataset Version Zip to Vending-from-box-to-segmentation-1 in coco-segmentation:: 100%|██████████| 16/16 [00:00<00:00, 211.70it/s]

# %%
VERSION=1
register_coco_instances("vending_train", {}, f"./Vending-from-box-to-segmentation-{VERSION}/train/_annotations.coco.json", f"./Vending-from-box-to-segmentation-{VERSION}/train/")
register_coco_instances("vending_valid", {}, f"./Vending-from-box-to-segmentation-{VERSION}/valid/_annotations.coco.json", f"./Vending-from-box-to-segmentation-{VERSION}/valid/")
register_coco_instances("vending_test", {}, f"./Vending-from-box-to-segmentation-{VERSION}/test/_annotations.coco.json", f"./Vending-from-box-to-segmentation-{VERSION}/test/")

# %%
dataset_train = DatasetCatalog.get("vending_train")
fig, ax = plt.subplots()
dataset_dict = random.choice(dataset_train)
im = Image.open(dataset_dict['file_name'])
ax.imshow(im)
for ann in dataset_dict['annotations']:
    for poly in ann['segmentation']:
        x = poly[0::2]
        y = poly[1::2]
        ax.plot(x,y, linewidth=2, color='red')
# Out:
# WARNING [04/30 13:24:48 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [04/30 13:24:48 d2.data.datasets.coco]: Loaded 5 images in COCO format from ./Vending-from-box-to-segmentation-1/train/_annotations.coco.json

# %% [markdown]
# # Configure Detectron2 for fine tuning from COCO, Define training loop helper functions (from detectron2 repo), Run custom training loop

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("vending_train",)#Train dataset registered in a previous cell
cfg.DATASETS.TEST = ("vending_test",)#Test dataset registered in a previous cell
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.00035
cfg.SOLVER.MAX_ITER = 5000 #We found that with a patience of 500, training will early stop before 10,000 iterations
cfg.SOLVER.STEPS = []
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 512
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 27 # 26 letters plus one super class
cfg.TEST.EVAL_PERIOD = 0 # Increase this number if you want to monitor validation performance during training

PATIENCE = 310 #Early stopping will occur after N iterations of no imporovement in total_loss

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)

# %%
def get_evaluator(cfg, dataset_name, output_folder=None):
    """
    Create evaluator(s) for a given dataset.
    This uses the special metadata "evaluator_type" associated with each builtin dataset.
    For your own dataset, you can simply create an evaluator manually in your
    script and do not have to worry about the hacky if-else logic here.
    """
    if output_folder is None:
        output_folder = os.path.join(cfg.OUTPUT_DIR, "inference")
    evaluator_list = []
    evaluator_type = MetadataCatalog.get(dataset_name).evaluator_type
    if evaluator_type in ["sem_seg", "coco_panoptic_seg"]:
        evaluator_list.append(
            SemSegEvaluator(
                dataset_name,
                distributed=True,
                output_dir=output_folder,
            )
        )
    if evaluator_type in ["coco", "coco_panoptic_seg"]:
        evaluator_list.append(COCOEvaluator(dataset_name, output_dir=output_folder))
    if evaluator_type == "coco_panoptic_seg":
        evaluator_list.append(COCOPanopticEvaluator(dataset_name, output_folder))
    if evaluator_type == "cityscapes_instance":
        return CityscapesInstanceEvaluator(dataset_name)
    if evaluator_type == "cityscapes_sem_seg":
        return CityscapesSemSegEvaluator(dataset_name)
    if evaluator_type == "pascal_voc":
        return PascalVOCDetectionEvaluator(dataset_name)
    if evaluator_type == "lvis":
        return LVISEvaluator(dataset_name, cfg, True, output_folder)
    if len(evaluator_list) == 0:
        raise NotImplementedError(
            "no Evaluator for the dataset {} with the type {}".format(dataset_name, evaluator_type)
        )
    if len(evaluator_list) == 1:
        return evaluator_list[0]
    return DatasetEvaluators(evaluator_list)

def do_test(cfg, model):
    results = OrderedDict()
    for dataset_name in cfg.DATASETS.TEST:
        data_loader = build_detection_test_loader(cfg, dataset_name)
        evaluator = get_evaluator(
            cfg, dataset_name, os.path.join(cfg.OUTPUT_DIR, "inference", dataset_name)
        )
        results_i = inference_on_dataset(model, data_loader, evaluator)
        results[dataset_name] = results_i
        if comm.is_main_process():
            logger.info("Evaluation results for {} in csv format:".format(dataset_name))
            print_csv_format(results_i)
    if len(results) == 1:
        results = list(results.values())[0]
    return results


logger = logging.getLogger("detectron2")
resume=False
model = build_model(cfg)
optimizer = build_optimizer(cfg, model)
scheduler = build_lr_scheduler(cfg, optimizer)

BEST_LOSS = np.inf

checkpointer = DetectionCheckpointer(
    model, cfg.OUTPUT_DIR, optimizer=optimizer, scheduler=scheduler
)
start_iter = (
    checkpointer.resume_or_load(cfg.MODEL.WEIGHTS, resume=resume).get("iteration", -1) + 1
)
prev_iter = start_iter
max_iter = cfg.SOLVER.MAX_ITER

periodic_checkpointer = PeriodicCheckpointer(
    checkpointer, cfg.SOLVER.CHECKPOINT_PERIOD, max_iter=max_iter
)

writers = default_writers(cfg.OUTPUT_DIR, max_iter) if comm.is_main_process() else []

# compared to "train_net.py", we do not support accurate timing and
# precise BN here, because they are not trivial to implement in a small training loop
data_loader = build_detection_train_loader(cfg)
logger.info("Starting training from iteration {}".format(start_iter))
patience_counter = 0
with EventStorage(start_iter) as storage:
    for data, iteration in zip(data_loader, range(start_iter, max_iter)):
        storage.iter = iteration

        loss_dict = model(data)
        losses = sum(loss_dict.values())
        assert torch.isfinite(losses).all(), loss_dict

        loss_dict_reduced = {k: v.item() for k, v in comm.reduce_dict(loss_dict).items()}
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())
        if comm.is_main_process():
            storage.put_scalars(total_loss=losses_reduced, **loss_dict_reduced)

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()
        storage.put_scalar("lr", optimizer.param_groups[0]["lr"], smoothing_hint=False)
        scheduler.step()

        if (
            cfg.TEST.EVAL_PERIOD > 0
            and (iteration + 1) % cfg.TEST.EVAL_PERIOD == 0
            and iteration != max_iter - 1
        ):
            do_test(cfg, model)
            # Compared to "train_net.py", the test results are not dumped to EventStorage
            comm.synchronize()

        if iteration - start_iter > 5 and (
            (iteration + 1) % 20 == 0 or iteration == max_iter - 1
        ):
            for writer in writers:
                writer.write()
        periodic_checkpointer.step(iteration)
        
        if iteration > prev_iter:
            prev_iter = iteration
            if losses_reduced < BEST_LOSS:
                BEST_LOSS = losses_reduced
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter % 100 == 0:
                    print(f"Loss has not improved for {patience_counter} iterations")
                if patience_counter >= PATIENCE:
                    print(f"EARLY STOPPING")
                    break
                
do_test(cfg, model)
# Out:
# [04/30 13:36:04 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (28, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (28,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (108, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (108,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (27, 256, 1, 1) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (27,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# WARNING [04/30 13:36:04 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [04/30 13:36:04 d2.data.datasets.coco]: Loaded 5 images in COCO format from ./Vending-from-box-to-segmentation-1/train/_annotations.coco.json
# [04/30 13:36:04 d2.data.build]: Removed 0 images with no usable annotations. 5 images left.
# [04/30 13:36:04 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [04/30 13:36:04 d2.data.build]: Using training sampler TrainingSampler
# [04/30 13:36:04 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [04/30 13:36:04 d2.data.common]: Serializing 5 elements to byte tensors and concatenating them all ...
# [04/30 13:36:04 d2.data.common]: Serialized dataset takes 0.23 MiB
# [04/30 13:36:04 detectron2]: Starting training from iteration 0
# [04/30 13:36:23 d2.utils.events]:  iter: 19  total_loss: 4.917  loss_cls: 3.268  loss_box_reg: 0.7937  loss_mask: 0.6947  loss_rpn_cls: 0.04551  loss_rpn_loc: 0.08469     lr: 6.9933e-06  max_mem: 4428M
# [04/30 13:36:44 d2.utils.events]:  eta: 1:24:14  iter: 39  total_loss: 4.643  loss_cls: 3.126  loss_box_reg: 0.7535  loss_mask: 0.6891  loss_rpn_cls: 0.04469  loss_rpn_loc: 0.08041     lr: 1.3986e-05  max_mem: 4428M
# [04/30 13:37:01 d2.utils.events]:  eta: 1:11:03  iter: 59  total_loss: 4.298  loss_cls: 2.791  loss_box_reg: 0.7599  loss_mask: 0.675  loss_rpn_cls: 0.03891  loss_rpn_loc: 0.08052     lr: 2.0979e-05  max_mem: 4428M
# [04/30 13:37:18 d2.utils.events]:  eta: 1:11:22  iter: 79  total_loss: 3.674  loss_cls: 2.21  loss_box_reg: 0.7485  loss_mask: 0.6538  loss_rpn_cls: 0.03322  loss_rpn_loc: 0.07952     lr: 2.7972e-05  max_mem: 4428M
# [04/30 13:37:37 d2.utils.events]:  eta: 1:16:20  iter: 99  total_loss: 2.888  loss_cls: 1.417  loss_box_reg: 0.7472  loss_mask: 0.6247  loss_rpn_cls: 0.03085  loss_rpn_loc: 0.07585     lr: 3.4965e-05  max_mem: 4428M
# [04/30 13:37:55 d2.utils.events]:  eta: 1:12:30  iter: 119  total_loss: 2.523  loss_cls: 1.094  loss_box_reg: 0.7356  loss_mask: 0.5858  loss_rpn_cls: 0.03374  loss_rpn_loc: 0.07142     lr: 4.1958e-05  max_mem: 4428M
# [04/30 13:38:13 d2.utils.events]:  eta: 1:12:00  iter: 139  total_loss: 2.247  loss_cls: 0.8663  loss_box_reg: 0.7183  loss_mask: 0.5427  loss_rpn_cls: 0.02479  loss_rpn_loc: 0.06864     lr: 4.8951e-05  max_mem: 4428M
# [04/30 13:38:32 d2.utils.events]:  eta: 1:16:15  iter: 159  total_loss: 1.964  loss_cls: 0.6818  loss_box_reg: 0.694  loss_mask: 0.5038  loss_rpn_cls: 0.02289  loss_rpn_loc: 0.06477     lr: 5.5944e-05  max_mem: 4428M
# [04/30 13:38:49 d2.utils.events]:  eta: 1:10:37  iter: 179  total_loss: 1.762  loss_cls: 0.5256  loss_box_reg: 0.6893  loss_mask: 0.4592  loss_rpn_cls: 0.01674  loss_rpn_loc: 0.05979     lr: 6.2937e-05  max_mem: 4428M
# [04/30 13:39:07 d2.utils.events]:  eta: 1:10:19  iter: 199  total_loss: 1.563  loss_cls: 0.4248  loss_box_reg: 0.6307  loss_mask: 0.4257  loss_rpn_cls: 0.02031  loss_rpn_loc: 0.05781     lr: 6.993e-05  max_mem: 4428M
# [04/30 13:39:26 d2.utils.events]:  eta: 1:17:46  iter: 219  total_loss: 1.411  loss_cls: 0.3516  loss_box_reg: 0.6186  loss_mask: 0.392  loss_rpn_cls: 0.01278  loss_rpn_loc: 0.05352     lr: 7.6923e-05  max_mem: 4428M
# [04/30 13:39:44 d2.utils.events]:  eta: 1:09:12  iter: 239  total_loss: 1.288  loss_cls: 0.2951  loss_box_reg: 0.551  loss_mask: 0.3463  loss_rpn_cls: 0.01485  loss_rpn_loc: 0.05457     lr: 8.3916e-05  max_mem: 4428M
# [04/30 13:40:02 d2.utils.events]:  eta: 1:12:47  iter: 259  total_loss: 1.152  loss_cls: 0.2563  loss_box_reg: 0.5086  loss_mask: 0.3043  loss_rpn_cls: 0.01221  loss_rpn_loc: 0.05379     lr: 9.0909e-05  max_mem: 4428M
# [04/30 13:40:21 d2.utils.events]:  eta: 1:12:04  iter: 279  total_loss: 0.9933  loss_cls: 0.2237  loss_box_reg: 0.4359  loss_mask: 0.2591  loss_rpn_cls: 0.009068  loss_rpn_loc: 0.05212     lr: 9.7902e-05  max_mem: 4428M
# [04/30 13:40:38 d2.utils.events]:  eta: 1:07:46  iter: 299  total_loss: 0.8629  loss_cls: 0.1976  loss_box_reg: 0.3515  loss_mask: 0.2282  loss_rpn_cls: 0.01371  loss_rpn_loc: 0.0496     lr: 0.0001049  max_mem: 4428M
# [04/30 13:40:56 d2.utils.events]:  eta: 1:10:07  iter: 319  total_loss: 0.7548  loss_cls: 0.1684  loss_box_reg: 0.3166  loss_mask: 0.209  loss_rpn_cls: 0.009238  loss_rpn_loc: 0.04751     lr: 0.00011189  max_mem: 4428M
# [04/30 13:41:14 d2.utils.events]:  eta: 1:11:29  iter: 339  total_loss: 0.7077  loss_cls: 0.159  loss_box_reg: 0.2827  loss_mask: 0.2004  loss_rpn_cls: 0.007987  loss_rpn_loc: 0.04565     lr: 0.00011888  max_mem: 4428M
# [04/30 13:41:32 d2.utils.events]:  eta: 1:07:03  iter: 359  total_loss: 0.6658  loss_cls: 0.148  loss_box_reg: 0.2722  loss_mask: 0.1913  loss_rpn_cls: 0.00486  loss_rpn_loc: 0.04379     lr: 0.00012587  max_mem: 4428M
# [04/30 13:41:49 d2.utils.events]:  eta: 1:06:16  iter: 379  total_loss: 0.6185  loss_cls: 0.1381  loss_box_reg: 0.2356  loss_mask: 0.1824  loss_rpn_cls: 0.002915  loss_rpn_loc: 0.03769     lr: 0.00013287  max_mem: 4428M
# [04/30 13:42:08 d2.utils.events]:  eta: 1:11:41  iter: 399  total_loss: 0.615  loss_cls: 0.1371  loss_box_reg: 0.2425  loss_mask: 0.1809  loss_rpn_cls: 0.002899  loss_rpn_loc: 0.0418     lr: 0.00013986  max_mem: 4428M
# [04/30 13:42:25 d2.utils.events]:  eta: 1:06:24  iter: 419  total_loss: 0.5841  loss_cls: 0.1332  loss_box_reg: 0.2256  loss_mask: 0.1695  loss_rpn_cls: 0.004268  loss_rpn_loc: 0.03965     lr: 0.00014685  max_mem: 4428M
# [04/30 13:42:42 d2.utils.events]:  eta: 1:06:20  iter: 439  total_loss: 0.5402  loss_cls: 0.1285  loss_box_reg: 0.1936  loss_mask: 0.1673  loss_rpn_cls: 0.001868  loss_rpn_loc: 0.03567     lr: 0.00015385  max_mem: 4428M
# [04/30 13:43:01 d2.utils.events]:  eta: 1:09:59  iter: 459  total_loss: 0.542  loss_cls: 0.1184  loss_box_reg: 0.2046  loss_mask: 0.1642  loss_rpn_cls: 0.006637  loss_rpn_loc: 0.03393     lr: 0.00016084  max_mem: 4428M
# [04/30 13:43:19 d2.utils.events]:  eta: 1:08:19  iter: 479  total_loss: 0.4986  loss_cls: 0.1082  loss_box_reg: 0.1776  loss_mask: 0.1559  loss_rpn_cls: 0.002594  loss_rpn_loc: 0.03464     lr: 0.00016783  max_mem: 4428M
# [04/30 13:43:36 d2.utils.events]:  eta: 1:05:02  iter: 499  total_loss: 0.4936  loss_cls: 0.107  loss_box_reg: 0.178  loss_mask: 0.1565  loss_rpn_cls: 0.001868  loss_rpn_loc: 0.02942     lr: 0.00017483  max_mem: 4428M
# [04/30 13:43:55 d2.utils.events]:  eta: 1:11:10  iter: 519  total_loss: 0.4766  loss_cls: 0.1057  loss_box_reg: 0.1785  loss_mask: 0.1488  loss_rpn_cls: 0.001872  loss_rpn_loc: 0.03032     lr: 0.00018182  max_mem: 4428M
# [04/30 13:44:13 d2.utils.events]:  eta: 1:05:18  iter: 539  total_loss: 0.4551  loss_cls: 0.1022  loss_box_reg: 0.1621  loss_mask: 0.1473  loss_rpn_cls: 0.0009389  loss_rpn_loc: 0.02844     lr: 0.00018881  max_mem: 4428M
# [04/30 13:44:30 d2.utils.events]:  eta: 1:02:48  iter: 559  total_loss: 0.4494  loss_cls: 0.1033  loss_box_reg: 0.149  loss_mask: 0.1434  loss_rpn_cls: 0.001583  loss_rpn_loc: 0.02731     lr: 0.0001958  max_mem: 4428M
# [04/30 13:44:49 d2.utils.events]:  eta: 1:09:03  iter: 579  total_loss: 0.4242  loss_cls: 0.0907  loss_box_reg: 0.1497  loss_mask: 0.1413  loss_rpn_cls: 0.0008874  loss_rpn_loc: 0.02534     lr: 0.0002028  max_mem: 4428M
# [04/30 13:45:06 d2.utils.events]:  eta: 1:03:23  iter: 599  total_loss: 0.4234  loss_cls: 0.09104  loss_box_reg: 0.1558  loss_mask: 0.1384  loss_rpn_cls: 0.001174  loss_rpn_loc: 0.02546     lr: 0.00020979  max_mem: 4428M
# [04/30 13:45:24 d2.utils.events]:  eta: 1:04:04  iter: 619  total_loss: 0.387  loss_cls: 0.08321  loss_box_reg: 0.1435  loss_mask: 0.1301  loss_rpn_cls: 0.001567  loss_rpn_loc: 0.02495     lr: 0.00021678  max_mem: 4428M
# [04/30 13:45:46 d2.utils.events]:  eta: 1:20:05  iter: 639  total_loss: 0.3799  loss_cls: 0.07978  loss_box_reg: 0.1377  loss_mask: 0.1266  loss_rpn_cls: 0.0012  loss_rpn_loc: 0.02373     lr: 0.00022378  max_mem: 4428M
# [04/30 13:46:03 d2.utils.events]:  eta: 1:02:50  iter: 659  total_loss: 0.3757  loss_cls: 0.07938  loss_box_reg: 0.1387  loss_mask: 0.1249  loss_rpn_cls: 0.0007256  loss_rpn_loc: 0.02273     lr: 0.00023077  max_mem: 4428M
# [04/30 13:46:22 d2.utils.events]:  eta: 1:07:37  iter: 679  total_loss: 0.3878  loss_cls: 0.07394  loss_box_reg: 0.1531  loss_mask: 0.1223  loss_rpn_cls: 0.0009952  loss_rpn_loc: 0.02446     lr: 0.00023776  max_mem: 4428M
# [04/30 13:46:39 d2.utils.events]:  eta: 1:02:35  iter: 699  total_loss: 0.3543  loss_cls: 0.07049  loss_box_reg: 0.1357  loss_mask: 0.1201  loss_rpn_cls: 0.0009872  loss_rpn_loc: 0.02562     lr: 0.00024476  max_mem: 4428M
# [04/30 13:46:58 d2.utils.events]:  eta: 1:07:18  iter: 719  total_loss: 0.3372  loss_cls: 0.06693  loss_box_reg: 0.1197  loss_mask: 0.1164  loss_rpn_cls: 0.0008062  loss_rpn_loc: 0.02702     lr: 0.00025175  max_mem: 4428M
# [04/30 13:47:17 d2.utils.events]:  eta: 1:06:18  iter: 739  total_loss: 0.3279  loss_cls: 0.06587  loss_box_reg: 0.1122  loss_mask: 0.1135  loss_rpn_cls: 0.0006004  loss_rpn_loc: 0.02062     lr: 0.00025874  max_mem: 4428M
# [04/30 13:47:34 d2.utils.events]:  eta: 1:01:16  iter: 759  total_loss: 0.3076  loss_cls: 0.06098  loss_box_reg: 0.1052  loss_mask: 0.111  loss_rpn_cls: 0.0006055  loss_rpn_loc: 0.01957     lr: 0.00026573  max_mem: 4428M
# [04/30 13:47:52 d2.utils.events]:  eta: 1:01:11  iter: 779  total_loss: 0.3142  loss_cls: 0.05943  loss_box_reg: 0.11  loss_mask: 0.1114  loss_rpn_cls: 0.0007866  loss_rpn_loc: 0.01999     lr: 0.00027273  max_mem: 4428M
# [04/30 13:48:10 d2.utils.events]:  eta: 1:05:23  iter: 799  total_loss: 0.2894  loss_cls: 0.05465  loss_box_reg: 0.1018  loss_mask: 0.106  loss_rpn_cls: 0.0004098  loss_rpn_loc: 0.01912     lr: 0.00027972  max_mem: 4428M
# [04/30 13:48:28 d2.utils.events]:  eta: 1:00:31  iter: 819  total_loss: 0.3166  loss_cls: 0.05634  loss_box_reg: 0.1218  loss_mask: 0.1053  loss_rpn_cls: 0.0004461  loss_rpn_loc: 0.0178     lr: 0.00028671  max_mem: 4428M
# [04/30 13:48:45 d2.utils.events]:  eta: 0:59:18  iter: 839  total_loss: 0.2885  loss_cls: 0.05257  loss_box_reg: 0.1091  loss_mask: 0.102  loss_rpn_cls: 0.0004056  loss_rpn_loc: 0.01665     lr: 0.00029371  max_mem: 4428M
# [04/30 13:49:03 d2.utils.events]:  eta: 1:04:32  iter: 859  total_loss: 0.2923  loss_cls: 0.05359  loss_box_reg: 0.1127  loss_mask: 0.1023  loss_rpn_cls: 0.0003756  loss_rpn_loc: 0.01863     lr: 0.0003007  max_mem: 4428M
# [04/30 13:49:21 d2.utils.events]:  eta: 1:00:22  iter: 879  total_loss: 0.2832  loss_cls: 0.05133  loss_box_reg: 0.104  loss_mask: 0.1008  loss_rpn_cls: 0.0005522  loss_rpn_loc: 0.02103     lr: 0.00030769  max_mem: 4428M
# [04/30 13:49:38 d2.utils.events]:  eta: 0:59:21  iter: 899  total_loss: 0.2675  loss_cls: 0.05166  loss_box_reg: 0.09661  loss_mask: 0.09789  loss_rpn_cls: 0.0005823  loss_rpn_loc: 0.0197     lr: 0.00031469  max_mem: 4428M
# [04/30 13:49:57 d2.utils.events]:  eta: 1:04:43  iter: 919  total_loss: 0.2579  loss_cls: 0.04853  loss_box_reg: 0.08795  loss_mask: 0.09699  loss_rpn_cls: 0.0007247  loss_rpn_loc: 0.0196     lr: 0.00032168  max_mem: 4428M
# [04/30 13:50:15 d2.utils.events]:  eta: 0:59:14  iter: 939  total_loss: 0.2813  loss_cls: 0.04521  loss_box_reg: 0.1125  loss_mask: 0.09445  loss_rpn_cls: 0.0006192  loss_rpn_loc: 0.0257     lr: 0.00032867  max_mem: 4428M
# [04/30 13:50:33 d2.utils.events]:  eta: 0:59:27  iter: 959  total_loss: 0.2722  loss_cls: 0.04791  loss_box_reg: 0.11  loss_mask: 0.09294  loss_rpn_cls: 0.0004364  loss_rpn_loc: 0.01937     lr: 0.00033566  max_mem: 4428M
# [04/30 13:50:52 d2.utils.events]:  eta: 1:04:12  iter: 979  total_loss: 0.2671  loss_cls: 0.04686  loss_box_reg: 0.09373  loss_mask: 0.09344  loss_rpn_cls: 0.0008332  loss_rpn_loc: 0.01686     lr: 0.00034266  max_mem: 4428M
# [04/30 13:51:09 d2.utils.events]:  eta: 0:57:52  iter: 999  total_loss: 0.2437  loss_cls: 0.044  loss_box_reg: 0.0836  loss_mask: 0.09379  loss_rpn_cls: 0.0005984  loss_rpn_loc: 0.01729     lr: 0.00034965  max_mem: 4428M
# [04/30 13:51:27 d2.utils.events]:  eta: 1:00:15  iter: 1019  total_loss: 0.243  loss_cls: 0.04063  loss_box_reg: 0.08677  loss_mask: 0.09105  loss_rpn_cls: 0.0006484  loss_rpn_loc: 0.01613     lr: 0.00035  max_mem: 4428M
# [04/30 13:51:46 d2.utils.events]:  eta: 1:03:06  iter: 1039  total_loss: 0.2418  loss_cls: 0.04061  loss_box_reg: 0.08233  loss_mask: 0.08848  loss_rpn_cls: 0.0003123  loss_rpn_loc: 0.01735     lr: 0.00035  max_mem: 4428M
# [04/30 13:52:04 d2.utils.events]:  eta: 0:58:45  iter: 1059  total_loss: 0.247  loss_cls: 0.0427  loss_box_reg: 0.09193  loss_mask: 0.08876  loss_rpn_cls: 0.0003498  loss_rpn_loc: 0.01995     lr: 0.00035  max_mem: 4428M
# [04/30 13:52:23 d2.utils.events]:  eta: 0:59:57  iter: 1079  total_loss: 0.256  loss_cls: 0.04411  loss_box_reg: 0.1011  loss_mask: 0.0883  loss_rpn_cls: 0.0003655  loss_rpn_loc: 0.02129     lr: 0.00035  max_mem: 4428M
# [04/30 13:52:41 d2.utils.events]:  eta: 1:00:39  iter: 1099  total_loss: 0.2327  loss_cls: 0.04289  loss_box_reg: 0.08326  loss_mask: 0.08637  loss_rpn_cls: 0.0005359  loss_rpn_loc: 0.01673     lr: 0.00035  max_mem: 4428M
# [04/30 13:52:59 d2.utils.events]:  eta: 0:57:07  iter: 1119  total_loss: 0.2602  loss_cls: 0.04421  loss_box_reg: 0.09661  loss_mask: 0.08671  loss_rpn_cls: 0.0005337  loss_rpn_loc: 0.0217     lr: 0.00035  max_mem: 4428M
# Loss has not improved for 100 iterations
# [04/30 13:53:17 d2.utils.events]:  eta: 0:58:52  iter: 1139  total_loss: 0.2562  loss_cls: 0.04107  loss_box_reg: 0.09947  loss_mask: 0.08682  loss_rpn_cls: 0.0005741  loss_rpn_loc: 0.02252     lr: 0.00035  max_mem: 4428M
# [04/30 13:53:37 d2.utils.events]:  eta: 1:03:05  iter: 1159  total_loss: 0.2356  loss_cls: 0.04002  loss_box_reg: 0.07969  loss_mask: 0.08633  loss_rpn_cls: 0.0006936  loss_rpn_loc: 0.01584     lr: 0.00035  max_mem: 4428M
# [04/30 13:53:54 d2.utils.events]:  eta: 0:55:04  iter: 1179  total_loss: 0.2143  loss_cls: 0.03891  loss_box_reg: 0.07008  loss_mask: 0.08608  loss_rpn_cls: 0.0005111  loss_rpn_loc: 0.01371     lr: 0.00035  max_mem: 4428M
# [04/30 13:54:13 d2.utils.events]:  eta: 0:58:37  iter: 1199  total_loss: 0.2101  loss_cls: 0.03612  loss_box_reg: 0.06897  loss_mask: 0.08346  loss_rpn_cls: 0.0005089  loss_rpn_loc: 0.01703     lr: 0.00035  max_mem: 4428M
# [04/30 13:54:31 d2.utils.events]:  eta: 0:56:21  iter: 1219  total_loss: 0.2247  loss_cls: 0.03755  loss_box_reg: 0.07746  loss_mask: 0.08456  loss_rpn_cls: 0.0005201  loss_rpn_loc: 0.01642     lr: 0.00035  max_mem: 4428M
# [04/30 13:54:48 d2.utils.events]:  eta: 0:55:41  iter: 1239  total_loss: 0.2117  loss_cls: 0.036  loss_box_reg: 0.07235  loss_mask: 0.08243  loss_rpn_cls: 0.0003957  loss_rpn_loc: 0.01404     lr: 0.00035  max_mem: 4428M
# [04/30 13:55:07 d2.utils.events]:  eta: 0:59:05  iter: 1259  total_loss: 0.1937  loss_cls: 0.03192  loss_box_reg: 0.06423  loss_mask: 0.08097  loss_rpn_cls: 0.0005565  loss_rpn_loc: 0.01224     lr: 0.00035  max_mem: 4428M
# [04/30 13:55:26 d2.utils.events]:  eta: 0:56:11  iter: 1279  total_loss: 0.2239  loss_cls: 0.0332  loss_box_reg: 0.0865  loss_mask: 0.08244  loss_rpn_cls: 0.0002916  loss_rpn_loc: 0.01721     lr: 0.00035  max_mem: 4428M
# [04/30 13:55:43 d2.utils.events]:  eta: 0:54:35  iter: 1299  total_loss: 0.2202  loss_cls: 0.03787  loss_box_reg: 0.08303  loss_mask: 0.08089  loss_rpn_cls: 0.0007013  loss_rpn_loc: 0.01924     lr: 0.00035  max_mem: 4428M
# [04/30 13:56:03 d2.utils.events]:  eta: 0:59:38  iter: 1319  total_loss: 0.2029  loss_cls: 0.03638  loss_box_reg: 0.06676  loss_mask: 0.07886  loss_rpn_cls: 0.0005296  loss_rpn_loc: 0.01636     lr: 0.00035  max_mem: 4428M
# [04/30 13:56:20 d2.utils.events]:  eta: 0:54:07  iter: 1339  total_loss: 0.2042  loss_cls: 0.0322  loss_box_reg: 0.06906  loss_mask: 0.07813  loss_rpn_cls: 0.0005856  loss_rpn_loc: 0.0175     lr: 0.00035  max_mem: 4428M
# [04/30 13:56:38 d2.utils.events]:  eta: 0:52:19  iter: 1359  total_loss: 0.1913  loss_cls: 0.02938  loss_box_reg: 0.06608  loss_mask: 0.08091  loss_rpn_cls: 0.0006648  loss_rpn_loc: 0.0124     lr: 0.00035  max_mem: 4428M
# [04/30 13:56:57 d2.utils.events]:  eta: 0:57:47  iter: 1379  total_loss: 0.2031  loss_cls: 0.0339  loss_box_reg: 0.0763  loss_mask: 0.07828  loss_rpn_cls: 0.0003416  loss_rpn_loc: 0.0123     lr: 0.00035  max_mem: 4428M
# [04/30 13:57:15 d2.utils.events]:  eta: 0:53:17  iter: 1399  total_loss: 0.2217  loss_cls: 0.0304  loss_box_reg: 0.09404  loss_mask: 0.07548  loss_rpn_cls: 0.000468  loss_rpn_loc: 0.01219     lr: 0.00035  max_mem: 4428M
# [04/30 13:57:33 d2.utils.events]:  eta: 0:54:42  iter: 1419  total_loss: 0.219  loss_cls: 0.03149  loss_box_reg: 0.09141  loss_mask: 0.07489  loss_rpn_cls: 0.0003504  loss_rpn_loc: 0.01519     lr: 0.00035  max_mem: 4428M
# Loss has not improved for 100 iterations
# [04/30 13:57:52 d2.utils.events]:  eta: 0:55:13  iter: 1439  total_loss: 0.1867  loss_cls: 0.02898  loss_box_reg: 0.06518  loss_mask: 0.07446  loss_rpn_cls: 0.000495  loss_rpn_loc: 0.01328     lr: 0.00035  max_mem: 4428M
# [04/30 13:58:10 d2.utils.events]:  eta: 0:52:59  iter: 1459  total_loss: 0.1808  loss_cls: 0.0275  loss_box_reg: 0.06075  loss_mask: 0.07576  loss_rpn_cls: 0.0004636  loss_rpn_loc: 0.01221     lr: 0.00035  max_mem: 4428M
# [04/30 13:58:27 d2.utils.events]:  eta: 0:51:36  iter: 1479  total_loss: 0.1762  loss_cls: 0.02611  loss_box_reg: 0.05544  loss_mask: 0.07426  loss_rpn_cls: 0.0005141  loss_rpn_loc: 0.01288     lr: 0.00035  max_mem: 4428M
# [04/30 13:58:46 d2.utils.events]:  eta: 0:56:07  iter: 1499  total_loss: 0.1953  loss_cls: 0.02764  loss_box_reg: 0.0765  loss_mask: 0.07547  loss_rpn_cls: 0.0003698  loss_rpn_loc: 0.01579     lr: 0.00035  max_mem: 4428M
# [04/30 13:59:04 d2.utils.events]:  eta: 0:51:16  iter: 1519  total_loss: 0.217  loss_cls: 0.02853  loss_box_reg: 0.08691  loss_mask: 0.07507  loss_rpn_cls: 0.0004587  loss_rpn_loc: 0.01688     lr: 0.00035  max_mem: 4428M
# [04/30 13:59:21 d2.utils.events]:  eta: 0:50:06  iter: 1539  total_loss: 0.1884  loss_cls: 0.02832  loss_box_reg: 0.06255  loss_mask: 0.07339  loss_rpn_cls: 0.0005705  loss_rpn_loc: 0.01387     lr: 0.00035  max_mem: 4428M
# [04/30 13:59:40 d2.utils.events]:  eta: 0:53:15  iter: 1559  total_loss: 0.1691  loss_cls: 0.02501  loss_box_reg: 0.05353  loss_mask: 0.07329  loss_rpn_cls: 0.0004528  loss_rpn_loc: 0.01232     lr: 0.00035  max_mem: 4428M
# [04/30 13:59:57 d2.utils.events]:  eta: 0:49:34  iter: 1579  total_loss: 0.1669  loss_cls: 0.02458  loss_box_reg: 0.05235  loss_mask: 0.07264  loss_rpn_cls: 0.0004287  loss_rpn_loc: 0.01414     lr: 0.00035  max_mem: 4428M
# [04/30 14:00:15 d2.utils.events]:  eta: 0:49:53  iter: 1599  total_loss: 0.1756  loss_cls: 0.02455  loss_box_reg: 0.05553  loss_mask: 0.07157  loss_rpn_cls: 0.0004574  loss_rpn_loc: 0.01717     lr: 0.00035  max_mem: 4428M
# [04/30 14:00:34 d2.utils.events]:  eta: 0:52:29  iter: 1619  total_loss: 0.1704  loss_cls: 0.02426  loss_box_reg: 0.05651  loss_mask: 0.07174  loss_rpn_cls: 0.0005592  loss_rpn_loc: 0.0136     lr: 0.00035  max_mem: 4428M
# [04/30 14:00:51 d2.utils.events]:  eta: 0:49:01  iter: 1639  total_loss: 0.1654  loss_cls: 0.0231  loss_box_reg: 0.05335  loss_mask: 0.07163  loss_rpn_cls: 0.0004378  loss_rpn_loc: 0.01279     lr: 0.00035  max_mem: 4428M
# [04/30 14:01:09 d2.utils.events]:  eta: 0:48:35  iter: 1659  total_loss: 0.1632  loss_cls: 0.02133  loss_box_reg: 0.0562  loss_mask: 0.07127  loss_rpn_cls: 0.0004158  loss_rpn_loc: 0.01289     lr: 0.00035  max_mem: 4428M
# [04/30 14:01:27 d2.utils.events]:  eta: 0:51:15  iter: 1679  total_loss: 0.1751  loss_cls: 0.02198  loss_box_reg: 0.0647  loss_mask: 0.06908  loss_rpn_cls: 0.0003976  loss_rpn_loc: 0.01145     lr: 0.00035  max_mem: 4428M
# [04/30 14:01:45 d2.utils.events]:  eta: 0:47:55  iter: 1699  total_loss: 0.1721  loss_cls: 0.02264  loss_box_reg: 0.06175  loss_mask: 0.07008  loss_rpn_cls: 0.0004574  loss_rpn_loc: 0.0129     lr: 0.00035  max_mem: 4428M
# [04/30 14:02:02 d2.utils.events]:  eta: 0:48:48  iter: 1719  total_loss: 0.177  loss_cls: 0.02118  loss_box_reg: 0.06803  loss_mask: 0.07156  loss_rpn_cls: 0.0005605  loss_rpn_loc: 0.01304     lr: 0.00035  max_mem: 4428M
# [04/30 14:02:21 d2.utils.events]:  eta: 0:50:05  iter: 1739  total_loss: 0.1764  loss_cls: 0.02341  loss_box_reg: 0.07033  loss_mask: 0.06914  loss_rpn_cls: 0.0004033  loss_rpn_loc: 0.01497     lr: 0.00035  max_mem: 4428M
# [04/30 14:02:39 d2.utils.events]:  eta: 0:48:06  iter: 1759  total_loss: 0.1745  loss_cls: 0.02424  loss_box_reg: 0.05935  loss_mask: 0.06854  loss_rpn_cls: 0.0004954  loss_rpn_loc: 0.01252     lr: 0.00035  max_mem: 4428M
# [04/30 14:02:57 d2.utils.events]:  eta: 0:48:12  iter: 1779  total_loss: 0.171  loss_cls: 0.02513  loss_box_reg: 0.05899  loss_mask: 0.07054  loss_rpn_cls: 0.000341  loss_rpn_loc: 0.01065     lr: 0.00035  max_mem: 4428M
# [04/30 14:03:16 d2.utils.events]:  eta: 0:52:38  iter: 1799  total_loss: 0.1643  loss_cls: 0.02341  loss_box_reg: 0.05379  loss_mask: 0.07016  loss_rpn_cls: 0.0003682  loss_rpn_loc: 0.01473     lr: 0.00035  max_mem: 4428M
# [04/30 14:03:34 d2.utils.events]:  eta: 0:46:19  iter: 1819  total_loss: 0.1605  loss_cls: 0.02398  loss_box_reg: 0.05101  loss_mask: 0.06798  loss_rpn_cls: 0.0005409  loss_rpn_loc: 0.0169     lr: 0.00035  max_mem: 4428M
# [04/30 14:03:52 d2.utils.events]:  eta: 0:48:26  iter: 1839  total_loss: 0.1623  loss_cls: 0.02378  loss_box_reg: 0.05301  loss_mask: 0.06641  loss_rpn_cls: 0.0004579  loss_rpn_loc: 0.01323     lr: 0.00035  max_mem: 4428M
# [04/30 14:04:10 d2.utils.events]:  eta: 0:47:27  iter: 1859  total_loss: 0.1588  loss_cls: 0.02236  loss_box_reg: 0.05094  loss_mask: 0.06695  loss_rpn_cls: 0.0006341  loss_rpn_loc: 0.01267     lr: 0.00035  max_mem: 4428M
# [04/30 14:04:28 d2.utils.events]:  eta: 0:45:09  iter: 1879  total_loss: 0.1548  loss_cls: 0.02072  loss_box_reg: 0.05406  loss_mask: 0.06782  loss_rpn_cls: 0.0005045  loss_rpn_loc: 0.01396     lr: 0.00035  max_mem: 4428M
# [04/30 14:04:46 d2.utils.events]:  eta: 0:47:31  iter: 1899  total_loss: 0.1563  loss_cls: 0.02046  loss_box_reg: 0.05334  loss_mask: 0.06799  loss_rpn_cls: 0.0004706  loss_rpn_loc: 0.01227     lr: 0.00035  max_mem: 4428M
# [04/30 14:05:04 d2.utils.events]:  eta: 0:46:30  iter: 1919  total_loss: 0.1555  loss_cls: 0.01879  loss_box_reg: 0.05392  loss_mask: 0.06699  loss_rpn_cls: 0.0004704  loss_rpn_loc: 0.01189     lr: 0.00035  max_mem: 4428M
# [04/30 14:05:22 d2.utils.events]:  eta: 0:44:27  iter: 1939  total_loss: 0.1602  loss_cls: 0.02161  loss_box_reg: 0.0562  loss_mask: 0.06741  loss_rpn_cls: 0.0004191  loss_rpn_loc: 0.01099     lr: 0.00035  max_mem: 4428M
# [04/30 14:05:40 d2.utils.events]:  eta: 0:46:42  iter: 1959  total_loss: 0.1719  loss_cls: 0.02103  loss_box_reg: 0.07056  loss_mask: 0.06785  loss_rpn_cls: 0.0003446  loss_rpn_loc: 0.01129     lr: 0.00035  max_mem: 4428M
# Loss has not improved for 100 iterations
# [04/30 14:05:59 d2.utils.events]:  eta: 0:46:52  iter: 1979  total_loss: 0.1677  loss_cls: 0.02132  loss_box_reg: 0.07259  loss_mask: 0.0659  loss_rpn_cls: 0.0003999  loss_rpn_loc: 0.01002     lr: 0.00035  max_mem: 4428M
# [04/30 14:06:17 d2.utils.events]:  eta: 0:44:48  iter: 1999  total_loss: 0.159  loss_cls: 0.02108  loss_box_reg: 0.05627  loss_mask: 0.06641  loss_rpn_cls: 0.0003598  loss_rpn_loc: 0.01201     lr: 0.00035  max_mem: 4428M
# [04/30 14:06:35 d2.utils.events]:  eta: 0:44:38  iter: 2019  total_loss: 0.1446  loss_cls: 0.01951  loss_box_reg: 0.04571  loss_mask: 0.0652  loss_rpn_cls: 0.000442  loss_rpn_loc: 0.01114     lr: 0.00035  max_mem: 4428M
# [04/30 14:06:53 d2.utils.events]:  eta: 0:46:00  iter: 2039  total_loss: 0.1421  loss_cls: 0.01908  loss_box_reg: 0.0425  loss_mask: 0.06444  loss_rpn_cls: 0.0004403  loss_rpn_loc: 0.01043     lr: 0.00035  max_mem: 4428M
# [04/30 14:07:11 d2.utils.events]:  eta: 0:43:30  iter: 2059  total_loss: 0.1572  loss_cls: 0.02182  loss_box_reg: 0.05407  loss_mask: 0.06545  loss_rpn_cls: 0.0004015  loss_rpn_loc: 0.0106     lr: 0.00035  max_mem: 4428M
# [04/30 14:07:29 d2.utils.events]:  eta: 0:43:39  iter: 2079  total_loss: 0.15  loss_cls: 0.01978  loss_box_reg: 0.04982  loss_mask: 0.06497  loss_rpn_cls: 0.0004343  loss_rpn_loc: 0.008891     lr: 0.00035  max_mem: 4428M
# [04/30 14:07:47 d2.utils.events]:  eta: 0:44:11  iter: 2099  total_loss: 0.1583  loss_cls: 0.02001  loss_box_reg: 0.06031  loss_mask: 0.06203  loss_rpn_cls: 0.0003829  loss_rpn_loc: 0.01179     lr: 0.00035  max_mem: 4428M
# [04/30 14:08:05 d2.utils.events]:  eta: 0:42:53  iter: 2119  total_loss: 0.1578  loss_cls: 0.01816  loss_box_reg: 0.05646  loss_mask: 0.06349  loss_rpn_cls: 0.0003732  loss_rpn_loc: 0.01183     lr: 0.00035  max_mem: 4428M
# [04/30 14:08:24 d2.utils.events]:  eta: 0:45:50  iter: 2139  total_loss: 0.1453  loss_cls: 0.02126  loss_box_reg: 0.0474  loss_mask: 0.06339  loss_rpn_cls: 0.0004115  loss_rpn_loc: 0.01046     lr: 0.00035  max_mem: 4428M
# [04/30 14:08:42 d2.utils.events]:  eta: 0:42:46  iter: 2159  total_loss: 0.1402  loss_cls: 0.0169  loss_box_reg: 0.04431  loss_mask: 0.06326  loss_rpn_cls: 0.0004504  loss_rpn_loc: 0.007984     lr: 0.00035  max_mem: 4428M
# [04/30 14:09:00 d2.utils.events]:  eta: 0:40:30  iter: 2179  total_loss: 0.1329  loss_cls: 0.01566  loss_box_reg: 0.04131  loss_mask: 0.06392  loss_rpn_cls: 0.000409  loss_rpn_loc: 0.009195     lr: 0.00035  max_mem: 4428M
# [04/30 14:09:19 d2.utils.events]:  eta: 0:45:02  iter: 2199  total_loss: 0.1392  loss_cls: 0.01648  loss_box_reg: 0.04195  loss_mask: 0.06028  loss_rpn_cls: 0.0004145  loss_rpn_loc: 0.01047     lr: 0.00035  max_mem: 4428M
# [04/30 14:09:36 d2.utils.events]:  eta: 0:39:38  iter: 2219  total_loss: 0.1569  loss_cls: 0.01638  loss_box_reg: 0.06132  loss_mask: 0.06167  loss_rpn_cls: 0.0003638  loss_rpn_loc: 0.01152     lr: 0.00035  max_mem: 4428M
# [04/30 14:09:54 d2.utils.events]:  eta: 0:40:16  iter: 2239  total_loss: 0.1708  loss_cls: 0.01815  loss_box_reg: 0.07342  loss_mask: 0.06417  loss_rpn_cls: 0.0003744  loss_rpn_loc: 0.01029     lr: 0.00035  max_mem: 4428M
# Loss has not improved for 100 iterations
# [04/30 14:10:13 d2.utils.events]:  eta: 0:43:55  iter: 2259  total_loss: 0.1495  loss_cls: 0.01924  loss_box_reg: 0.05276  loss_mask: 0.06329  loss_rpn_cls: 0.0003567  loss_rpn_loc: 0.0101     lr: 0.00035  max_mem: 4428M
# [04/30 14:10:30 d2.utils.events]:  eta: 0:39:44  iter: 2279  total_loss: 0.1392  loss_cls: 0.01829  loss_box_reg: 0.04462  loss_mask: 0.06138  loss_rpn_cls: 0.0003694  loss_rpn_loc: 0.0103     lr: 0.00035  max_mem: 4428M
# [04/30 14:10:48 d2.utils.events]:  eta: 0:39:23  iter: 2299  total_loss: 0.1382  loss_cls: 0.01676  loss_box_reg: 0.04615  loss_mask: 0.06331  loss_rpn_cls: 0.0003628  loss_rpn_loc: 0.01021     lr: 0.00035  max_mem: 4428M
# [04/30 14:11:07 d2.utils.events]:  eta: 0:42:12  iter: 2319  total_loss: 0.1422  loss_cls: 0.01836  loss_box_reg: 0.04879  loss_mask: 0.06206  loss_rpn_cls: 0.0004058  loss_rpn_loc: 0.008945     lr: 0.00035  max_mem: 4428M
# [04/30 14:11:24 d2.utils.events]:  eta: 0:38:31  iter: 2339  total_loss: 0.1409  loss_cls: 0.01765  loss_box_reg: 0.04756  loss_mask: 0.06292  loss_rpn_cls: 0.0003348  loss_rpn_loc: 0.0102     lr: 0.00035  max_mem: 4428M
# Loss has not improved for 200 iterations
# [04/30 14:11:42 d2.utils.events]:  eta: 0:38:03  iter: 2359  total_loss: 0.1388  loss_cls: 0.01718  loss_box_reg: 0.04474  loss_mask: 0.06105  loss_rpn_cls: 0.0004249  loss_rpn_loc: 0.01107     lr: 0.00035  max_mem: 4428M
# [04/30 14:12:00 d2.utils.events]:  eta: 0:40:47  iter: 2379  total_loss: 0.1449  loss_cls: 0.01647  loss_box_reg: 0.04942  loss_mask: 0.06104  loss_rpn_cls: 0.0005037  loss_rpn_loc: 0.01236     lr: 0.00035  max_mem: 4428M
# [04/30 14:12:18 d2.utils.events]:  eta: 0:39:13  iter: 2399  total_loss: 0.151  loss_cls: 0.01871  loss_box_reg: 0.05589  loss_mask: 0.06175  loss_rpn_cls: 0.0004304  loss_rpn_loc: 0.01084     lr: 0.00035  max_mem: 4428M
# [04/30 14:12:36 d2.utils.events]:  eta: 0:37:08  iter: 2419  total_loss: 0.1386  loss_cls: 0.0155  loss_box_reg: 0.0514  loss_mask: 0.05999  loss_rpn_cls: 0.0004653  loss_rpn_loc: 0.0102     lr: 0.00035  max_mem: 4428M
# [04/30 14:12:54 d2.utils.events]:  eta: 0:39:55  iter: 2439  total_loss: 0.1477  loss_cls: 0.01664  loss_box_reg: 0.0534  loss_mask: 0.06143  loss_rpn_cls: 0.0004183  loss_rpn_loc: 0.01056     lr: 0.00035  max_mem: 4428M
# Loss has not improved for 100 iterations
# [04/30 14:13:11 d2.utils.events]:  eta: 0:36:21  iter: 2459  total_loss: 0.1318  loss_cls: 0.01512  loss_box_reg: 0.04227  loss_mask: 0.05912  loss_rpn_cls: 0.0004219  loss_rpn_loc: 0.008479     lr: 0.00035  max_mem: 4428M
# [04/30 14:13:29 d2.utils.events]:  eta: 0:36:44  iter: 2479  total_loss: 0.14  loss_cls: 0.017  loss_box_reg: 0.05319  loss_mask: 0.06017  loss_rpn_cls: 0.0003634  loss_rpn_loc: 0.008754     lr: 0.00035  max_mem: 4428M
# [04/30 14:13:47 d2.utils.events]:  eta: 0:38:25  iter: 2499  total_loss: 0.1366  loss_cls: 0.01599  loss_box_reg: 0.04749  loss_mask: 0.0584  loss_rpn_cls: 0.0003373  loss_rpn_loc: 0.01055     lr: 0.00035  max_mem: 4428M
# [04/30 14:14:05 d2.utils.events]:  eta: 0:36:55  iter: 2519  total_loss: 0.1515  loss_cls: 0.01845  loss_box_reg: 0.05419  loss_mask: 0.05875  loss_rpn_cls: 0.0003416  loss_rpn_loc: 0.01188     lr: 0.00035  max_mem: 4428M
# [04/30 14:14:23 d2.utils.events]:  eta: 0:35:28  iter: 2539  total_loss: 0.1433  loss_cls: 0.01738  loss_box_reg: 0.04683  loss_mask: 0.06041  loss_rpn_cls: 0.0004247  loss_rpn_loc: 0.01252     lr: 0.00035  max_mem: 4428M
# Loss has not improved for 200 iterations
# [04/30 14:14:41 d2.utils.events]:  eta: 0:37:29  iter: 2559  total_loss: 0.1413  loss_cls: 0.0168  loss_box_reg: 0.04156  loss_mask: 0.05912  loss_rpn_cls: 0.0003695  loss_rpn_loc: 0.01279     lr: 0.00035  max_mem: 4428M
# [04/30 14:14:59 d2.utils.events]:  eta: 0:36:07  iter: 2579  total_loss: 0.1358  loss_cls: 0.01607  loss_box_reg: 0.04191  loss_mask: 0.05827  loss_rpn_cls: 0.0005635  loss_rpn_loc: 0.01412     lr: 0.00035  max_mem: 4428M
# [04/30 14:15:16 d2.utils.events]:  eta: 0:34:43  iter: 2599  total_loss: 0.134  loss_cls: 0.01534  loss_box_reg: 0.04705  loss_mask: 0.05632  loss_rpn_cls: 0.0005464  loss_rpn_loc: 0.0115     lr: 0.00035  max_mem: 4428M
# [04/30 14:15:34 d2.utils.events]:  eta: 0:34:36  iter: 2619  total_loss: 0.1427  loss_cls: 0.01664  loss_box_reg: 0.05223  loss_mask: 0.05979  loss_rpn_cls: 0.0004427  loss_rpn_loc: 0.01098     lr: 0.00035  max_mem: 4428M
# [04/30 14:15:52 d2.utils.events]:  eta: 0:36:07  iter: 2639  total_loss: 0.1305  loss_cls: 0.01494  loss_box_reg: 0.0435  loss_mask: 0.06126  loss_rpn_cls: 0.000367  loss_rpn_loc: 0.009539     lr: 0.00035  max_mem: 4428M
# [04/30 14:16:09 d2.utils.events]:  eta: 0:33:12  iter: 2659  total_loss: 0.1233  loss_cls: 0.01361  loss_box_reg: 0.03738  loss_mask: 0.05751  loss_rpn_cls: 0.0004321  loss_rpn_loc: 0.01119     lr: 0.00035  max_mem: 4428M
# [04/30 14:16:27 d2.utils.events]:  eta: 0:34:33  iter: 2679  total_loss: 0.1391  loss_cls: 0.01476  loss_box_reg: 0.05144  loss_mask: 0.05837  loss_rpn_cls: 0.0004094  loss_rpn_loc: 0.009997     lr: 0.00035  max_mem: 4428M
# [04/30 14:16:46 d2.utils.events]:  eta: 0:36:03  iter: 2699  total_loss: 0.1314  loss_cls: 0.01429  loss_box_reg: 0.0498  loss_mask: 0.05926  loss_rpn_cls: 0.0003977  loss_rpn_loc: 0.008468     lr: 0.00035  max_mem: 4428M
# [04/30 14:17:03 d2.utils.events]:  eta: 0:32:52  iter: 2719  total_loss: 0.13  loss_cls: 0.01556  loss_box_reg: 0.04823  loss_mask: 0.05885  loss_rpn_cls: 0.0003567  loss_rpn_loc: 0.007235     lr: 0.00035  max_mem: 4428M
# [04/30 14:17:21 d2.utils.events]:  eta: 0:33:24  iter: 2739  total_loss: 0.1365  loss_cls: 0.0156  loss_box_reg: 0.04608  loss_mask: 0.05589  loss_rpn_cls: 0.0003689  loss_rpn_loc: 0.01033     lr: 0.00035  max_mem: 4428M
# [04/30 14:17:39 d2.utils.events]:  eta: 0:34:08  iter: 2759  total_loss: 0.139  loss_cls: 0.01492  loss_box_reg: 0.05156  loss_mask: 0.05814  loss_rpn_cls: 0.0004046  loss_rpn_loc: 0.01088     lr: 0.00035  max_mem: 4428M
# [04/30 14:17:56 d2.utils.events]:  eta: 0:31:49  iter: 2779  total_loss: 0.1437  loss_cls: 0.01714  loss_box_reg: 0.05585  loss_mask: 0.0568  loss_rpn_cls: 0.0004626  loss_rpn_loc: 0.009411     lr: 0.00035  max_mem: 4428M
# Loss has not improved for 100 iterations
# [04/30 14:18:14 d2.utils.events]:  eta: 0:31:36  iter: 2799  total_loss: 0.1342  loss_cls: 0.01556  loss_box_reg: 0.04536  loss_mask: 0.0571  loss_rpn_cls: 0.0003809  loss_rpn_loc: 0.00999     lr: 0.00035  max_mem: 4428M
# [04/30 14:18:32 d2.utils.events]:  eta: 0:33:21  iter: 2819  total_loss: 0.1332  loss_cls: 0.0167  loss_box_reg: 0.04749  loss_mask: 0.05613  loss_rpn_cls: 0.0003948  loss_rpn_loc: 0.009577     lr: 0.00035  max_mem: 4428M
# [04/30 14:18:49 d2.utils.events]:  eta: 0:31:00  iter: 2839  total_loss: 0.1263  loss_cls: 0.01516  loss_box_reg: 0.03987  loss_mask: 0.05635  loss_rpn_cls: 0.0004379  loss_rpn_loc: 0.009576     lr: 0.00035  max_mem: 4428M
# [04/30 14:19:06 d2.utils.events]:  eta: 0:30:37  iter: 2859  total_loss: 0.1195  loss_cls: 0.0146  loss_box_reg: 0.0382  loss_mask: 0.05505  loss_rpn_cls: 0.0004371  loss_rpn_loc: 0.008426     lr: 0.00035  max_mem: 4428M
# [04/30 14:19:25 d2.utils.events]:  eta: 0:32:57  iter: 2879  total_loss: 0.1304  loss_cls: 0.01531  loss_box_reg: 0.04402  loss_mask: 0.05545  loss_rpn_cls: 0.0005085  loss_rpn_loc: 0.0118     lr: 0.00035  max_mem: 4428M
# [04/30 14:19:42 d2.utils.events]:  eta: 0:30:15  iter: 2899  total_loss: 0.1425  loss_cls: 0.01674  loss_box_reg: 0.05762  loss_mask: 0.05512  loss_rpn_cls: 0.0004799  loss_rpn_loc: 0.01255     lr: 0.00035  max_mem: 4428M
# [04/30 14:20:00 d2.utils.events]:  eta: 0:30:04  iter: 2919  total_loss: 0.1407  loss_cls: 0.0145  loss_box_reg: 0.05185  loss_mask: 0.0552  loss_rpn_cls: 0.0005118  loss_rpn_loc: 0.01152     lr: 0.00035  max_mem: 4428M
# [04/30 14:20:19 d2.utils.events]:  eta: 0:32:17  iter: 2939  total_loss: 0.1228  loss_cls: 0.01604  loss_box_reg: 0.03561  loss_mask: 0.05526  loss_rpn_cls: 0.0004998  loss_rpn_loc: 0.01098     lr: 0.00035  max_mem: 4428M
# Loss has not improved for 100 iterations
# [04/30 14:20:36 d2.utils.events]:  eta: 0:29:25  iter: 2959  total_loss: 0.1238  loss_cls: 0.01499  loss_box_reg: 0.03653  loss_mask: 0.05521  loss_rpn_cls: 0.0005497  loss_rpn_loc: 0.009619     lr: 0.00035  max_mem: 4428M
# [04/30 14:20:53 d2.utils.events]:  eta: 0:29:35  iter: 2979  total_loss: 0.1228  loss_cls: 0.01354  loss_box_reg: 0.03916  loss_mask: 0.05499  loss_rpn_cls: 0.0004708  loss_rpn_loc: 0.01205     lr: 0.00035  max_mem: 4428M
# [04/30 14:21:11 d2.utils.events]:  eta: 0:29:30  iter: 2999  total_loss: 0.1298  loss_cls: 0.01494  loss_box_reg: 0.04664  loss_mask: 0.05535  loss_rpn_cls: 0.0003444  loss_rpn_loc: 0.01192     lr: 0.00035  max_mem: 4428M
# [04/30 14:21:30 d2.utils.events]:  eta: 0:30:27  iter: 3019  total_loss: 0.1259  loss_cls: 0.01509  loss_box_reg: 0.04125  loss_mask: 0.05395  loss_rpn_cls: 0.0004684  loss_rpn_loc: 0.0101     lr: 0.00035  max_mem: 4428M
# [04/30 14:21:47 d2.utils.events]:  eta: 0:28:13  iter: 3039  total_loss: 0.1239  loss_cls: 0.0136  loss_box_reg: 0.04159  loss_mask: 0.05533  loss_rpn_cls: 0.0003553  loss_rpn_loc: 0.008333     lr: 0.00035  max_mem: 4428M
# Loss has not improved for 100 iterations
# [04/30 14:22:06 d2.utils.events]:  eta: 0:31:36  iter: 3059  total_loss: 0.1143  loss_cls: 0.01225  loss_box_reg: 0.03685  loss_mask: 0.05352  loss_rpn_cls: 0.0003995  loss_rpn_loc: 0.009168     lr: 0.00035  max_mem: 4428M
# [04/30 14:22:24 d2.utils.events]:  eta: 0:28:13  iter: 3079  total_loss: 0.1197  loss_cls: 0.01275  loss_box_reg: 0.03962  loss_mask: 0.05434  loss_rpn_cls: 0.0004048  loss_rpn_loc: 0.00835     lr: 0.00035  max_mem: 4428M
# [04/30 14:22:41 d2.utils.events]:  eta: 0:27:22  iter: 3099  total_loss: 0.141  loss_cls: 0.01365  loss_box_reg: 0.05461  loss_mask: 0.05616  loss_rpn_cls: 0.0004274  loss_rpn_loc: 0.01348     lr: 0.00035  max_mem: 4428M
# [04/30 14:23:00 d2.utils.events]:  eta: 0:29:30  iter: 3119  total_loss: 0.1217  loss_cls: 0.01297  loss_box_reg: 0.0397  loss_mask: 0.0545  loss_rpn_cls: 0.00048  loss_rpn_loc: 0.01088     lr: 0.00035  max_mem: 4428M
# [04/30 14:23:17 d2.utils.events]:  eta: 0:26:50  iter: 3139  total_loss: 0.1155  loss_cls: 0.01367  loss_box_reg: 0.03733  loss_mask: 0.05288  loss_rpn_cls: 0.000453  loss_rpn_loc: 0.007771     lr: 0.00035  max_mem: 4428M
# [04/30 14:23:34 d2.utils.events]:  eta: 0:26:00  iter: 3159  total_loss: 0.1153  loss_cls: 0.01357  loss_box_reg: 0.03572  loss_mask: 0.0537  loss_rpn_cls: 0.0004094  loss_rpn_loc: 0.01061     lr: 0.00035  max_mem: 4428M
# Loss has not improved for 100 iterations
# [04/30 14:23:52 d2.utils.events]:  eta: 0:27:16  iter: 3179  total_loss: 0.1177  loss_cls: 0.01333  loss_box_reg: 0.03495  loss_mask: 0.05403  loss_rpn_cls: 0.0003883  loss_rpn_loc: 0.009803     lr: 0.00035  max_mem: 4428M
# [04/30 14:24:10 d2.utils.events]:  eta: 0:26:57  iter: 3199  total_loss: 0.1113  loss_cls: 0.01354  loss_box_reg: 0.03327  loss_mask: 0.05412  loss_rpn_cls: 0.0003927  loss_rpn_loc: 0.008877     lr: 0.00035  max_mem: 4428M
# [04/30 14:24:28 d2.utils.events]:  eta: 0:25:39  iter: 3219  total_loss: 0.1197  loss_cls: 0.0132  loss_box_reg: 0.04438  loss_mask: 0.05345  loss_rpn_cls: 0.0003523  loss_rpn_loc: 0.007791     lr: 0.00035  max_mem: 4428M
# [04/30 14:24:45 d2.utils.events]:  eta: 0:25:45  iter: 3239  total_loss: 0.1131  loss_cls: 0.01322  loss_box_reg: 0.03539  loss_mask: 0.05308  loss_rpn_cls: 0.0003114  loss_rpn_loc: 0.007542     lr: 0.00035  max_mem: 4428M
# [04/30 14:25:03 d2.utils.events]:  eta: 0:26:16  iter: 3259  total_loss: 0.1169  loss_cls: 0.01318  loss_box_reg: 0.03769  loss_mask: 0.05315  loss_rpn_cls: 0.0003587  loss_rpn_loc: 0.0111     lr: 0.00035  max_mem: 4428M
# [04/30 14:25:21 d2.utils.events]:  eta: 0:24:47  iter: 3279  total_loss: 0.1377  loss_cls: 0.01536  loss_box_reg: 0.0499  loss_mask: 0.0544  loss_rpn_cls: 0.0004249  loss_rpn_loc: 0.01271     lr: 0.00035  max_mem: 4428M
# [04/30 14:25:38 d2.utils.events]:  eta: 0:24:12  iter: 3299  total_loss: 0.1298  loss_cls: 0.01381  loss_box_reg: 0.04566  loss_mask: 0.05417  loss_rpn_cls: 0.0004914  loss_rpn_loc: 0.00921     lr: 0.00035  max_mem: 4428M
# [04/30 14:25:56 d2.utils.events]:  eta: 0:26:10  iter: 3319  total_loss: 0.1198  loss_cls: 0.01267  loss_box_reg: 0.04306  loss_mask: 0.0535  loss_rpn_cls: 0.0004029  loss_rpn_loc: 0.009342     lr: 0.00035  max_mem: 4428M
# Loss has not improved for 100 iterations
# [04/30 14:26:14 d2.utils.events]:  eta: 0:23:42  iter: 3339  total_loss: 0.135  loss_cls: 0.01401  loss_box_reg: 0.05893  loss_mask: 0.05341  loss_rpn_cls: 0.0003661  loss_rpn_loc: 0.007799     lr: 0.00035  max_mem: 4428M
# [04/30 14:26:31 d2.utils.events]:  eta: 0:23:41  iter: 3359  total_loss: 0.1561  loss_cls: 0.01495  loss_box_reg: 0.0761  loss_mask: 0.05422  loss_rpn_cls: 0.000366  loss_rpn_loc: 0.009652     lr: 0.00035  max_mem: 4428M
# [04/30 14:26:50 d2.utils.events]:  eta: 0:25:13  iter: 3379  total_loss: 0.1345  loss_cls: 0.01525  loss_box_reg: 0.05113  loss_mask: 0.05376  loss_rpn_cls: 0.0003835  loss_rpn_loc: 0.009085     lr: 0.00035  max_mem: 4428M
# [04/30 14:27:07 d2.utils.events]:  eta: 0:22:56  iter: 3399  total_loss: 0.1168  loss_cls: 0.0141  loss_box_reg: 0.04009  loss_mask: 0.05333  loss_rpn_cls: 0.0003053  loss_rpn_loc: 0.008781     lr: 0.00035  max_mem: 4428M
# [04/30 14:27:24 d2.utils.events]:  eta: 0:22:40  iter: 3419  total_loss: 0.1158  loss_cls: 0.01325  loss_box_reg: 0.03889  loss_mask: 0.05227  loss_rpn_cls: 0.0004101  loss_rpn_loc: 0.008716     lr: 0.00035  max_mem: 4428M
# Loss has not improved for 200 iterations
# [04/30 14:27:43 d2.utils.events]:  eta: 0:24:03  iter: 3439  total_loss: 0.1116  loss_cls: 0.01281  loss_box_reg: 0.03557  loss_mask: 0.05235  loss_rpn_cls: 0.0004338  loss_rpn_loc: 0.007512     lr: 0.00035  max_mem: 4428M
# [04/30 14:28:00 d2.utils.events]:  eta: 0:22:39  iter: 3459  total_loss: 0.1059  loss_cls: 0.01148  loss_box_reg: 0.02921  loss_mask: 0.05248  loss_rpn_cls: 0.0004052  loss_rpn_loc: 0.009501     lr: 0.00035  max_mem: 4428M
# [04/30 14:28:17 d2.utils.events]:  eta: 0:21:50  iter: 3479  total_loss: 0.1177  loss_cls: 0.01256  loss_box_reg: 0.04014  loss_mask: 0.05279  loss_rpn_cls: 0.0004506  loss_rpn_loc: 0.009075     lr: 0.00035  max_mem: 4428M
# [04/30 14:28:36 d2.utils.events]:  eta: 0:23:41  iter: 3499  total_loss: 0.1194  loss_cls: 0.01261  loss_box_reg: 0.04356  loss_mask: 0.05165  loss_rpn_cls: 0.0004154  loss_rpn_loc: 0.007515     lr: 0.00035  max_mem: 4428M
# [04/30 14:28:54 d2.utils.events]:  eta: 0:21:29  iter: 3519  total_loss: 0.1315  loss_cls: 0.01477  loss_box_reg: 0.04437  loss_mask: 0.05263  loss_rpn_cls: 0.0004417  loss_rpn_loc: 0.01292     lr: 0.00035  max_mem: 4428M
# Loss has not improved for 300 iterations
# EARLY STOPPING
# WARNING [04/30 14:29:07 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [04/30 14:29:07 d2.data.datasets.coco]: Loaded 2 images in COCO format from ./Vending-from-box-to-segmentation-1/test/_annotations.coco.json
# [04/30 14:29:07 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [04/30 14:29:07 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [04/30 14:29:07 d2.data.common]: Serializing 2 elements to byte tensors and concatenating them all ...
# [04/30 14:29:07 d2.data.common]: Serialized dataset takes 0.08 MiB
# [04/30 14:29:07 d2.evaluation.evaluator]: Start inference on 2 batches
# [04/30 14:29:11 d2.evaluation.evaluator]: Total inference time: 0:00:01.675766 (1.675766 s / iter per device, on 1 devices)
# [04/30 14:29:11 d2.evaluation.evaluator]: Total inference pure compute time: 0:00:00 (0.245475 s / iter per device, on 1 devices)
# [04/30 14:29:11 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [04/30 14:29:11 d2.evaluation.coco_evaluation]: Saving results to ./output/inference/vending_test/coco_instances_results.json
# [04/30 14:29:11 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [04/30 14:29:11 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [04/30 14:29:11 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.01 seconds.
# [04/30 14:29:11 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [04/30 14:29:11 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.589
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.769
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.743
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.589
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.039
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.664
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.664
# [04/30 14:29:11 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |   AP   |  AP50  |  AP75  |  APs  |  APm  |  APl   |
# |:------:|:------:|:------:|:-----:|:-----:|:------:|
# | 58.872 | 76.882 | 74.267 |  nan  |  nan  | 58.872 |
# [04/30 14:29:11 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [04/30 14:29:11 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category             | AP   | category   | AP     | category   | AP     |
# |:---------------------|:-----|:-----------|:-------|:-----------|:-------|
# | from-HW1-to-HW2-food | nan  | drink      | 69.868 | food       | 47.877 |
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!
# [04/30 14:29:11 d2.evaluation.fast_eval_api]: Evaluate annotation type *segm*
# [04/30 14:29:11 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 0.01 seconds.
# [04/30 14:29:11 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [04/30 14:29:11 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.01 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.573
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.769
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.701
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.573
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.036
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.394
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.652
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.652
# [04/30 14:29:11 d2.evaluation.coco_evaluation]: Evaluation results for segm:
# |   AP   |  AP50  |  AP75  |  APs  |  APm  |  APl   |
# |:------:|:------:|:------:|:-----:|:-----:|:------:|
# | 57.336 | 76.882 | 70.128 |  nan  |  nan  | 57.336 |
# [04/30 14:29:11 d2.evaluation.coco_evaluation]: Some metrics cannot be computed and is shown as NaN.
# [04/30 14:29:11 d2.evaluation.coco_evaluation]: Per-category segm AP:
# | category             | AP   | category   | AP     | category   | AP     |
# |:---------------------|:-----|:-----------|:-------|:-----------|:-------|
# | from-HW1-to-HW2-food | nan  | drink      | 70.159 | food       | 44.513 |
# [04/30 14:29:11 detectron2]: Evaluation results for vending_test in csv format:
# [04/30 14:29:11 d2.evaluation.testing]: copypaste: Task: bbox
# [04/30 14:29:11 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [04/30 14:29:11 d2.evaluation.testing]: copypaste: 58.8724,76.8822,74.2674,nan,nan,58.8724
# [04/30 14:29:11 d2.evaluation.testing]: copypaste: Task: segm
# [04/30 14:29:11 d2.evaluation.testing]: copypaste: AP,AP50,AP75,APs,APm,APl
# [04/30 14:29:11 d2.evaluation.testing]: copypaste: 57.3363,76.8822,70.1278,nan,nan,57.3363
# OrderedDict([('bbox',
#               {'AP': 58.872392620182104,
#                'AP50': 76.88218412444273,
#                'AP75': 74.26739778188772,
#                'APs': nan,
#                'APm': nan,
#                'APl': 58.872392620182104,
#                'AP-from-HW1-to-HW2-food': nan,
#                'AP-drink': 69.86775184705091,
#                'AP-food': 47.87703339331329}),
#              ('segm',
#               {'AP': 57.336269172852795,
#                'AP50': 76.88218412444273,
#                'AP75': 70.12775140654543,
#                'APs': nan,
#                'APm': nan,
#                'APl': 57.336269172852795,
#                'AP-from-HW1-to-HW2-food': nan,
#                'AP-drink': 70.15907059231455,
#                'AP-food': 44.513467753391026})])

# %% [markdown]
# # Test model and show example output

# %%
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")  # path to the model we just trained
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.2   # set a custom testing threshold
predictor = DefaultPredictor(cfg)

dataset_dicts = DatasetCatalog.get("vending_valid")
for d in random.sample(dataset_dicts, 1):    
    im = cv2.imread(d["file_name"])
    outputs = predictor(im)
    v = Visualizer(im[:, :, ::-1],
                   scale=0.5, 
                   instance_mode=ColorMode.IMAGE_BW
    )
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    im = Image.fromarray(out.get_image()[:, :, ::-1])
    im
# Out:
# [04/30 14:30:53 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from ./output/model_final.pth ...
# WARNING [04/30 14:30:53 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [04/30 14:30:53 d2.data.datasets.coco]: Loaded 1 images in COCO format from ./Vending-from-box-to-segmentation-1/valid/_annotations.coco.json

# %%
im
# Out:
# <PIL.Image.Image image mode=RGB size=2304x1040 at 0x7F86368C0F10>

# %% [markdown]
# # Download trained model for future inference

# %%
from google.colab import files
files.download(os.path.join(cfg.OUTPUT_DIR, "model_final.pth"))
